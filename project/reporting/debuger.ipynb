# %%
import pandas as pd

# 1. Indiquez le chemin vers le fichier .pkl généré par le décorateur
chemin_dump = "./debug_dumps/rep_42_admission_data.pkl"

# 2. Chargez le fichier (il reconstruit instantanément le DataFrame Pandas)
df_analyse = pd.read_pickle(chemin_dump)

# 3. Affichez la variable pour déclencher les outils visuels de VS Code
df_analyse
# Out:
#    code_diag                                   description type_hospi  \
# 0        I21                    Infarctus aigu du myocarde          H
# 1        I21                    Infarctus aigu du myocarde          F
# 2        I21                    Infarctus aigu du myocarde          M
# 3        I21                    Infarctus aigu du myocarde          L
# 4        J44  Maladies pulmonaires obstructives chroniques          H
# 5        J44  Maladies pulmonaires obstructives chroniques          F
# 6        J44  Maladies pulmonaires obstructives chroniques          M
# 7        J44  Maladies pulmonaires obstructives chroniques          L
# 8        E11                       Diabète sucré de type 2          H
# 9        E11                       Diabète sucré de type 2          F
# 10       E11                       Diabète sucré de type 2          M
# 11       E11                       Diabète sucré de type 2          L
# ...
