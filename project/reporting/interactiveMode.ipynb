# %%
# !quarto render report1.qmd  -o rapport_SH_Z_3_1_fr.pdf   -P lang=nl  --no-cache
# Out:
# Executing 'report1.quarto_ipynb_2'
#   Cell 1/13: ''...................Done
#   Cell 2/13: ''...................Done
#   Cell 3/13: 'init-modules'.......Done
#   Cell 4/13: ''...................Done
#   Cell 5/13: ''...................Done
#   Cell 6/13: ''...................Done
#   Cell 7/13: 'tableau-erreurs'....Done
#   Cell 8/13: ''...................Done
#   Cell 9/13: ''...................Done
#   Cell 10/13: 'tableau-erreurs2'...Done
#   Cell 11/13: ''...................Done
#   Cell 12/13: ''...................Done
#   Cell 13/13: ''...................Done
#
# pandoc -o report1.typ
#   to: typst
#   standalone: true
#   shift-heading-level-by: -1
#   default-image-extension: svg
#   wrap: none
#   citeproc: false
#   variables: {}
#
# metadata
#   engines:
#     - path: /usr/local/lib/python3.12/dist-packages/quarto_cli/share/extension-subtrees/julia-engine/_extensions/julia-engine/julia-engine.js
#   mainfont: '="Open sans"'
#   papersize: a4
#   margin:
#     x: 2.5cm
# ...
